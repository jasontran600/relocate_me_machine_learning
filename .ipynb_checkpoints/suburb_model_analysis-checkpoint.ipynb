# %%
import os
from math import ceil 
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
from scipy.spatial import distance
from geopy.geocoders import Nominatim # converts an address into latitude and longitude values
from scipy.ndimage.filters import gaussian_filter1d
from sklearn import preprocessing
from sklearn.decomposition import PCA
import folium

# %% [markdown]
# # Suburb Analysis
# Load files

# %%
aus_suburbs = pd.read_csv(os.path.join('aus_suburbs.csv'), index_col=0)
venues_grouped = pd.read_csv(os.path.join('venues_grouped.csv'), index_col=0)
venues_sorted = pd.read_csv(os.path.join('venues_sorted.csv'), index_col=0)
ABS_data = pd.read_csv(os.path.join('ABS_2016_data.csv'), index_col=0)

# %%
ABS_data.columns.values.tolist()
# Out:
# ['Suburb',
#  'State',
#  'Age_0-4 years_count',
#  'Age_0-4 years_percentage',
#  'Age_10-14 years_count',
#  'Age_10-14 years_percentage',
#  'Age_15-19 years_count',
#  'Age_15-19 years_percentage',
#  'Age_20-24 years_count',
#  'Age_20-24 years_percentage',
#  'Age_25-29 years_count',
#  'Age_25-29 years_percentage',
#  'Age_30-34 years_count',
#  'Age_30-34 years_percentage',
#  'Age_35-39 years_count',
#  'Age_35-39 years_percentage',
#  'Age_40-44 years_count',
#  'Age_40-44 years_percentage',
#  'Age_45-49 years_count',
#  'Age_45-49 years_percentage',
#  'Age_5-9 years_count',
#  'Age_5-9 years_percentage',
#  'Age_50-54 years_count',
#  'Age_50-54 years_percentage',
#  'Age_55-59 years_count',
#  'Age_55-59 years_percentage',
#  'Age_60-64 years_count',
#  'Age_60-64 years_percentage',
#  'Age_65-69 years_count',
#  'Age_65-69 years_percentage',
#  'Age_70-74 years_count',
#  'Age_70-74 years_percentage',
#  'Age_75-79 years_count',
#  'Age_75-79 years_percentage',
#  'Age_80-84 years_count',
#  'Age_80-84 years_percentage',
#  'Age_85 years and over_count',
#  'Age_85 years and over_percentage',
#  'Age_Median age',
#  'All private dwellings_All private dwellings_count',
#  'All private dwellings_Average motor vehicles per dwelling_count',
#  'All private dwellings_Average number of people per household_count',
#  'All private dwellings_Median monthly mortgage repayments_count',
#  'All private dwellings_Median weekly household income_count',
#  'All private dwellings_Median weekly rent_count',
#  'Country of birth of father and/or mother, stated responses_Both parents born in Australia_count',
#  'Country of birth of father and/or mother, stated responses_Both parents born in Australia_percentage',
#  'Country of birth of father and/or mother, stated responses_Both parents born overseas_count',
#  'Country of birth of father and/or mother, stated responses_Both parents born overseas_percentage',
#  'Country of birth of father and/or mother, stated responses_Father only born overseas_count',
#  'Country of birth of father and/or mother, stated responses_Father only born overseas_percentage',
#  'Country of birth of father and/or mother, stated responses_Mother only born overseas_count',
#  'Country of birth of father and/or mother, stated responses_Mother only born overseas_percentage',
#  'Country of birth_Australia_count',
#  'Country of birth_Australia_percentage',
#  'Country of birth_Other top responses_count',
#  'Country of birth_Other top responses_percentage',
#  'Dwelling characteristics_Average number of people per household_count',
#  'Dwelling characteristics_Average number of people per household_percentage',
#  'Dwelling characteristics_Average number of persons per bedroom_count',
#  'Dwelling characteristics_Average number of persons per bedroom_percentage',
#  'Dwelling characteristics_Median weekly household income_count',
#  'Dwelling characteristics_Median weekly household income_percentage',
#  'Dwelling count_Occupied private dwellings_count',
#  'Dwelling count_Occupied private dwellings_percentage',
#  'Dwelling count_Unoccupied private dwellings_count',
#  'Dwelling count_Unoccupied private dwellings_percentage',
#  'Dwelling internet connection_Internet accessed from dwelling_count',
#  'Dwelling internet connection_Internet accessed from dwelling_percentage',
#  'Dwelling internet connection_Internet not accessed from dwelling_count',
#  'Dwelling internet connection_Internet not accessed from dwelling_percentage',
#  'Dwelling internet connection_Not stated_count',
#  'Dwelling internet connection_Not stated_percentage',
#  'Dwelling structure_Flat or apartment_count',
#  'Dwelling structure_Flat or apartment_percentage',
#  'Dwelling structure_Other dwelling_count',
#  'Dwelling structure_Other dwelling_percentage',
#  'Dwelling structure_Semi-detached, row or terrace house, townhouse etc_count',
#  'Dwelling structure_Semi-detached, row or terrace house, townhouse etc_percentage',
#  'Dwelling structure_Separate house_count',
#  'Dwelling structure_Separate house_percentage',
#  'Education_Not stated_count',
#  'Education_Not stated_percentage',
#  'Education_Other_count',
#  'Education_Other_percentage',
#  'Education_Preschool_count',
#  'Education_Preschool_percentage',
#  'Education_Primary - Catholic_count',
#  'Education_Primary - Catholic_percentage',
#  'Education_Primary - Government_count',
#  'Education_Primary - Government_percentage',
#  'Education_Primary - other non Government_count',
#  'Education_Primary - other non Government_percentage',
#  'Education_Secondary - Catholic_count',
#  'Education_Secondary - Catholic_percentage',
#  'Education_Secondary - Government_count',
#  'Education_Secondary - Government_percentage',
#  'Education_Secondary - other non Government_count',
#  'Education_Secondary - other non Government_percentage',
#  'Education_Technical or further education institution_count',
#  'Education_Technical or further education institution_percentage',
#  'Education_University or tertiary institution_count',
#  'Education_University or tertiary institution_percentage',
#  'Employment - hours worked_1-15 hours per week_count',
#  'Employment - hours worked_1-15 hours per week_percentage',
#  'Employment - hours worked_16-24 hours per week_count',
#  'Employment - hours worked_16-24 hours per week_percentage',
#  'Employment - hours worked_25-34 hours per week_count',
#  'Employment - hours worked_25-34 hours per week_percentage',
#  'Employment - hours worked_35-39 hours per week_count',
#  'Employment - hours worked_35-39 hours per week_percentage',
#  'Employment - hours worked_40 hours or more per week_count',
#  'Employment - hours worked_40 hours or more per week_percentage',
#  'Employment status of parents in couple families_Both employed, worked full-time_count',
#  'Employment status of parents in couple families_Both employed, worked full-time_percentage',
#  'Employment status of parents in couple families_Both employed, worked part-time_count',
#  'Employment status of parents in couple families_Both employed, worked part-time_percentage',
#  'Employment status of parents in couple families_Both not working_count',
#  'Employment status of parents in couple families_Both not working_percentage',
#  'Employment status of parents in couple families_Labour force status not stated (by one or both parents in a couple family)_count',
#  'Employment status of parents in couple families_Labour force status not stated (by one or both parents in a couple family)_percentage',
#  'Employment status of parents in couple families_One employed full-time, one part-time_count',
#  'Employment status of parents in couple families_One employed full-time, one part-time_percentage',
#  'Employment status of parents in couple families_One employed full-time, other not working_count',
#  'Employment status of parents in couple families_One employed full-time, other not working_percentage',
#  'Employment status of parents in couple families_One employed part-time, other not working_count',
#  'Employment status of parents in couple families_One employed part-time, other not working_percentage',
#  'Employment status of parents in couple families_Other (includes away from work)_count',
#  'Employment status of parents in couple families_Other (includes away from work)_percentage',
#  'Employment_Away from work_count',
#  'Employment_Away from work_percentage',
#  'Employment_Unemployed_count',
#  'Employment_Unemployed_percentage',
#  'Employment_Worked full-time_count',
#  'Employment_Worked full-time_percentage',
#  'Employment_Worked part-time_count',
#  'Employment_Worked part-time_percentage',
#  'Families_Avg children per family_for all families_count',
#  'Families_Avg children per family_for families with children_count',
#  'Families_Families_count',
#  'Family composition_Couple family with children_count',
#  'Family composition_Couple family with children_percentage',
#  'Family composition_Couple family without children_count',
#  'Family composition_Couple family without children_percentage',
#  'Family composition_One parent family_count',
#  'Family composition_One parent family_percentage',
#  'Family composition_Other family_count',
#  'Family composition_Other family_percentage',
#  'Household composition_Family households_count',
#  'Household composition_Family households_percentage',
#  'Household composition_Group households_count',
#  'Household composition_Group households_percentage',
#  'Household composition_Single (or lone) person households_count',
#  'Household composition_Single (or lone) person households_percentage',
#  'Household income_Less than $650 gross weekly income_count',
#  'Household income_Less than $650 gross weekly income_percentage',
#  'Household income_More than $3000 gross weekly income_count',
#  'Household income_More than $3000 gross weekly income_percentage',
#  'Level of highest educational attainment_Advanced Diploma and Diploma level_count',
#  'Level of highest educational attainment_Advanced Diploma and Diploma level_percentage',
#  'Level of highest educational attainment_Bachelor Degree level and above_count',
#  'Level of highest educational attainment_Bachelor Degree level and above_percentage',
#  'Level of highest educational attainment_Certificate level III_count',
#  'Level of highest educational attainment_Certificate level III_percentage',
#  'Level of highest educational attainment_Certificate level II_count',
#  'Level of highest educational attainment_Certificate level II_percentage',
#  'Level of highest educational attainment_Certificate level IV_count',
#  'Level of highest educational attainment_Certificate level IV_percentage',
#  'Level of highest educational attainment_Certificate level I_count',
#  'Level of highest educational attainment_Certificate level I_percentage',
#  'Level of highest educational attainment_No educational attainment_count',
#  'Level of highest educational attainment_No educational attainment_percentage',
#  'Level of highest educational attainment_Not stated_count',
#  'Level of highest educational attainment_Not stated_percentage',
#  'Level of highest educational attainment_Year 10_count',
#  'Level of highest educational attainment_Year 10_percentage',
#  'Level of highest educational attainment_Year 11_count',
#  'Level of highest educational attainment_Year 11_percentage',
#  'Level of highest educational attainment_Year 12_count',
#  'Level of highest educational attainment_Year 12_percentage',
#  'Level of highest educational attainment_Year 9 or below_count',
#  'Level of highest educational attainment_Year 9 or below_percentage',
#  'Median weekly incomes_Family_count',
#  'Median weekly incomes_Family_percentage',
#  'Median weekly incomes_Household_count',
#  'Median weekly incomes_Household_percentage',
#  'Median weekly incomes_Personal_count',
#  'Median weekly incomes_Personal_percentage',
#  'Mortgage and rent_Median monthly mortgage repayments_count',
#  'Mortgage and rent_Median monthly mortgage repayments_percentage',
#  'Mortgage and rent_Median weekly rent_count',
#  'Mortgage and rent_Median weekly rent_percentage',
#  'Mortgage monthly repayments_Households where mortgage repayments are less than 30% of household income_count',
#  'Mortgage monthly repayments_Households where mortgage repayments are less than 30% of household income_percentage',
#  'Mortgage monthly repayments_Households with mortgage repayments greater than or equal to 30% of household income_count',
#  'Mortgage monthly repayments_Households with mortgage repayments greater than or equal to 30% of household income_percentage',
#  'Mortgage monthly repayments_Median mortgage repayments_count',
#  'Mortgage monthly repayments_Median mortgage repayments_percentage',
#  'Number of bedrooms_1 bedroom_count',
#  'Number of bedrooms_1 bedroom_percentage',
#  'Number of bedrooms_2 bedrooms_count',
#  'Number of bedrooms_2 bedrooms_percentage',
#  'Number of bedrooms_3 bedrooms_count',
#  'Number of bedrooms_3 bedrooms_percentage',
#  'Number of bedrooms_4 or more bedrooms_count',
#  'Number of bedrooms_4 or more bedrooms_percentage',
#  'Number of bedrooms_Average number of bedrooms per dwelling_count',
#  'Number of bedrooms_Average number of bedrooms per dwelling_percentage',
#  'Number of bedrooms_Average number of people per household_count',
#  'Number of bedrooms_Average number of people per household_percentage',
#  'Number of bedrooms_None (includes bedsitters)_count',
#  'Number of bedrooms_None (includes bedsitters)_percentage',
#  'Number of bedrooms_Number of bedrooms not stated_count',
#  'Number of bedrooms_Number of bedrooms not stated_percentage',
#  'Number of registered motor vehicles_1 motor vehicle_count',
#  'Number of registered motor vehicles_1 motor vehicle_percentage',
#  'Number of registered motor vehicles_2 motor vehicles_count',
#  'Number of registered motor vehicles_2 motor vehicles_percentage',
#  'Number of registered motor vehicles_3 or more vehicles_count',
#  'Number of registered motor vehicles_3 or more vehicles_percentage',
#  'Number of registered motor vehicles_None_count',
#  'Number of registered motor vehicles_None_percentage',
#  'Number of registered motor vehicles_Number of motor vehicles not stated_count',
#  'Number of registered motor vehicles_Number of motor vehicles not stated_percentage',
#  'People characteristics_Female_count',
#  'People characteristics_Female_percentage',
#  'People characteristics_Male_count',
#  'People characteristics_Male_percentage',
#  'People characteristics_Median age_count',
#  'People characteristics_Median age_percentage',
#  'People_Aboriginal and/or Torres Strait Islander people_count',
#  'People_Aboriginal and/or Torres Strait Islander people_percentage',
#  'People_Female_count',
#  'People_Female_percentage',
#  'People_Male_count',
#  'People_Male_percentage',
#  'People_People_count',
#  'Registered marital status_Divorced_count',
#  'Registered marital status_Divorced_percentage',
#  'Registered marital status_Married_count',
#  'Registered marital status_Married_percentage',
#  'Registered marital status_Never married_count',
#  'Registered marital status_Never married_percentage',
#  'Registered marital status_Separated_count',
#  'Registered marital status_Separated_percentage',
#  'Registered marital status_Widowed_count',
#  'Registered marital status_Widowed_percentage',
#  'Rent weekly payments_Households where rent payments are less than 30% of household income_count',
#  'Rent weekly payments_Households where rent payments are less than 30% of household income_percentage',
#  'Rent weekly payments_Households with rent payments greater than or equal to 30% of household income_count',
#  'Rent weekly payments_Households with rent payments greater than or equal to 30% of household income_percentage',
#  'Rent weekly payments_Median rent',
#  'Single (or lone) parents_Female_count',
#  'Single (or lone) parents_Female_percentage',
#  'Single (or lone) parents_Male_count',
#  'Single (or lone) parents_Male_percentage',
#  'Social marital status_De facto marriage_count',
#  'Social marital status_De facto marriage_percentage',
#  'Social marital status_Not married_count',
#  'Social marital status_Not married_percentage',
#  'Social marital status_Registered marriage_count',
#  'Social marital status_Registered marriage_percentage',
#  'Tenure_Other tenure type_count',
#  'Tenure_Other tenure type_percentage',
#  'Tenure_Owned outright_count',
#  'Tenure_Owned outright_percentage',
#  'Tenure_Owned with a mortgage_count',
#  'Tenure_Owned with a mortgage_percentage',
#  'Tenure_Rented_count',
#  'Tenure_Rented_percentage',
#  'Tenure_Tenure type not stated_count',
#  'Tenure_Tenure type not stated_percentage',
#  'Unpaid domestic work, number of hours_15 to 29 hours per week_count',
#  'Unpaid domestic work, number of hours_15 to 29 hours per week_percentage',
#  'Unpaid domestic work, number of hours_30 hours or more per week_count',
#  'Unpaid domestic work, number of hours_30 hours or more per week_percentage',
#  'Unpaid domestic work, number of hours_5 to 14 hours per week_count',
#  'Unpaid domestic work, number of hours_5 to 14 hours per week_percentage',
#  'Unpaid domestic work, number of hours_Less than 5 hours per week_count',
#  'Unpaid domestic work, number of hours_Less than 5 hours per week_percentage',
#  'Unpaid work_Cared for child/children (last two weeks)_count',
#  'Unpaid work_Cared for child/children (last two weeks)_percentage',
#  'Unpaid work_Did unpaid domestic work (last week)_count',
#  'Unpaid work_Did unpaid domestic work (last week)_percentage',
#  'Unpaid work_Did voluntary work through an organisation or group (last 12 months)_count',
#  'Unpaid work_Did voluntary work through an organisation or group (last 12 months)_percentage',
#  'Unpaid work_Provided unpaid assistance to a person with a disability (last two weeks)_count',
#  'Unpaid work_Provided unpaid assistance to a person with a disability (last two weeks)_percentage']

# %% [markdown]
# # User input
# First we need the users input.

# %%
input_suburb = {'Suburb':'South Yarra', 'City':'Melbourne'}

input_city = 'Sydney'

print('Your ideal suburb is:')
print('')
print('* {}, {}'.format(input_suburb['Suburb'], input_suburb['City']))
print('')
print('And you would like to find similar suburbs in {}.'.format(input_city))
# Out:
# Your ideal suburb is:
#
# * South Yarra, Melbourne
#
# And you would like to find similar suburbs in Sydney.

# %% [markdown]
# # Get data

# %% [markdown]
# Transform data to a normal distribution with yeo-johnson transformation because box-cox only works with positive numbers whereas yeo-johnson works with both negative and postive. Distance column contains 0km for distance to cbd for cbds.

# %%
aus_suburbs_temp = aus_suburbs[['Suburb',
                                'area',
                                'density',
                                'distance']]
ABS_data_temp = ABS_data[['State',
                          'Age_Median age',
                          'Rent weekly payments_Median rent',
                          'People_People_count',
                          'Families_Families_count',
                          'Family composition_Couple family with children_count',
                          'Family composition_Couple family without children_count',
                          'Family composition_One parent family_count',
                          'Family composition_Other family_count']]

temp_data = pd.concat([aus_suburbs_temp, ABS_data_temp], axis=1, sort=False)

# Rename columns
temp_data.rename({'Age_Median age':'median_age',
                  'Rent weekly payments_Median rent':'median_rent',
                  'Families_Families_count':'Families_count'}, axis=1, inplace=True)

# %%
# Fill missing density data
temp_data['density'] = temp_data.apply(
    lambda row: row['People_People_count']/row['area'] if row['density'] == 0
                                                           else row['density'], axis=1)

# %%
temp_data.head()
# Out:
#            Suburb   area      density   distance State  median_age  \
# 0      Abbotsbury  4.833   879.991724  32.080970   NSW        38.0
# 1      Abbotsford  0.994  5405.432596   7.800763   NSW        45.0
# 2      Abbotsford  1.827  4479.474548   3.216681   Vic        32.0
# 3      Aberfeldie  1.602  2432.584270   7.313313   Vic        40.0
# 4  Aberfoyle Park  5.777  1910.853384  16.033313    SA        40.0
#
#    median_rent  People_People_count  Families_count  \
# 0        505.0               4253.0             NaN
# 1        520.0               5380.0             NaN
# 2        426.0               8192.0             NaN
# 3        351.0               3898.0             NaN
# 4        320.0              11046.0             NaN
#
#    Family composition_Couple family with children_count  \
# 0                                              739.0
# 1                                              614.0
# 2                                              489.0
# 3                                              597.0
# 4                                             1550.0
#
#    Family composition_Couple family without children_count  \
# 0                                              263.0
# 1                                              662.0
# 2                                             1164.0
# 3                                              287.0
# 4                                             1163.0
#
#    Family composition_One parent family_count  \
# 0                                       159.0
# 1                                       230.0
# 2                                       154.0
# 3                                       129.0
# 4                                       466.0
#
#    Family composition_Other family_count
# 0                                   15.0
# 1                                   29.0
# 2                                   81.0
# 3                                   13.0
# 4                                   24.0

# %%
# Fill missing families count data
temp_data['Families_count'] = temp_data.apply(
    lambda row: row['Family composition_Couple family with children_count'] + 
                row['Family composition_Couple family without children_count'] +
                row['Family composition_One parent family_count'] + 
                row['Family composition_Other family_count'] if np.isnan(row['Families_count'])
                                                           else row['Families_count'], axis=1
)

temp_data['family_percentage'] = temp_data['Families_count']/temp_data['People_People_count']

# %%
# Fill missing median age
means = temp_data.groupby(['State'])['median_age'].mean()
temp_data = temp_data.set_index(['State'])
temp_data['median_age'] = temp_data['median_age'].fillna(means)
temp_data = temp_data.reset_index()

# %%
# Fill missing median rent
means = temp_data.groupby(['State'])['median_rent'].mean()
temp_data = temp_data.set_index(['State'])
temp_data['median_rent'] = temp_data['median_rent'].fillna(means)
temp_data = temp_data.reset_index()

# Round off rent
temp_data['median_rent'] = temp_data.median_rent.map(lambda x: round(x,1))

# %%
#Drop columns
columns = ['State',
           'Suburb',
           'People_People_count',
           'Families_count',
           'Family composition_Couple family with children_count',
           'Family composition_Couple family without children_count',
           'Family composition_One parent family_count',
           'Family composition_Other family_count']

temp_data.drop(columns, inplace=True, axis=1)

# %%
temp_data.dropna(subset=['density','median_age', 'median_rent'], inplace=True)

# %%
temp_data.shape
# Out:
# (2534, 6)

# %%
temp_data.head()
# Out:
#     area      density   distance  median_age  median_rent  family_percentage
# 0  4.833   879.991724  32.080970        38.0        505.0           0.276511
# 1  0.994  5405.432596   7.800763        45.0        520.0           0.285316
# 2  1.827  4479.474548   3.216681        32.0        426.0           0.230469
# 3  1.602  2432.584270   7.313313        40.0        351.0           0.263212
# 4  5.777  1910.853384  16.033313        40.0        320.0           0.289969

# %% [markdown]
# # Geographic Analysis

# %%
# Transform data
geographic_df = temp_data[['area', 'distance', 'median_rent']]
geographic_df['area'] = np.log(geographic_df['area'])
geographic_df['distance'] = np.sqrt(geographic_df['distance'])
geographic_df['median_rent'] = (geographic_df['median_rent'])

# Add suburb and postcode labels to rows
geographic_df.insert(0, 'Suburb_id', aus_suburbs.Suburb_id)
geographic_df.insert(1, 'Suburb', aus_suburbs.Suburb)
geographic_df.insert(2, 'Postcode', aus_suburbs.Postcode)
geographic_df.insert(3, 'LGA', aus_suburbs.LGA)
geographic_df.insert(4, 'City', aus_suburbs.City)
# Out:
# /Users/Jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/Jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# /Users/Jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
plt.hist(geographic_df.distance.values)
# Out:
# (array([ 78., 284., 441., 468., 395., 351., 247., 176.,  72.,  22.]),
#  array([0.81369437, 1.64807614, 2.48245792, 3.3168397 , 4.15122148,
#         4.98560325, 5.81998503, 6.65436681, 7.48874858, 8.32313036,
#         9.15751214]),
#  <a list of 10 Patch objects>)

# %%
data = geographic_df.drop(columns=['Suburb_id', 'Suburb', 'Postcode', 'LGA', 'City'], axis=1)

pca = PCA()
pca.fit(data)
pca_data = pca.transform(data)

percentage_variation = np.round(pca.explained_variance_ratio_ * 100, decimals=1)
labels = ['PC' + str(x) for x in range(1, len(percentage_variation)+1)]

plt.bar(x=range(1,len(percentage_variation)+1), height=percentage_variation, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Figure 1: Scree Plot')
plt.show()

# %%
print('PC1: {}'.format(pca.explained_variance_ratio_[0]))
print('PC2: {}'.format(pca.explained_variance_ratio_[1]))
print('PC3: {}'.format(pca.explained_variance_ratio_[2]))
# Out:
# PC1: 0.9997230526799503
# PC2: 0.00022474410418087747
# PC3: 5.220321586885588e-05

# %%
pca_df = pd.DataFrame(pca_data, columns=labels)

plt.figure(figsize=(10,10))
plt.scatter(pca_df.PC1, pca_df.PC2)
plt.title(' Figure 2: PCA graph')
plt.xlabel('PC1 = {}%'.format(percentage_variation[0]))
plt.ylabel('PC2 = {}%'.format(percentage_variation[1]))
# plt.xlim(-5,5)
# plt.ylim(-5,5)
# Out:
# Text(0, 0.5, 'PC2 = 0.0%')

# %%
# The normalised variance of each attribute for all three principle components.
pd.DataFrame(pca.components_,columns=data.columns,index = ['PC1','PC2','PC3'])
# Out:
#          area  distance  median_rent
# PC1 -0.002247 -0.002797     0.999994
# PC2  0.531242  0.847213     0.003563
# PC3 -0.847217  0.531246    -0.000418

# %%
# Add suburb and postcode labels to rows
geographic_df = pca_df
geographic_df.insert(0, 'Suburb_id', aus_suburbs.Suburb_id)
geographic_df.insert(1, 'Suburb', aus_suburbs.Suburb)
geographic_df.insert(2, 'Postcode', aus_suburbs.Postcode)
geographic_df.insert(3, 'LGA', aus_suburbs.LGA)
geographic_df.insert(4, 'City', aus_suburbs.City)

# Drop PC3 column
geographic_df.drop(columns='PC3', axis=1, inplace=True)

# %% [markdown]
# # Geographic KNN

# %%
# Input data
input_suburb_df = geographic_df.loc[(geographic_df.Suburb == input_suburb['Suburb']) &
                              (geographic_df.City == input_suburb['City'])]
input_city_df = geographic_df.loc[geographic_df.City == input_city]

# Dataframe for pairwise calculation
knn_df = pd.concat([input_suburb_df, input_city_df], ignore_index=True)

# Convert dataframe to array
values_df = knn_df.drop(['Suburb_id', 'Suburb', 'City', 'Postcode', 'LGA'], axis=1)
values_array = values_df.values

# Pairwise calculation
D = distance.squareform(distance.pdist(values_array))
D = D[0]

# Convert pairwise distances to dataframe
knn_dist = pd.DataFrame(data=D.flatten())

# Add distances to full geographic dataframe
knn_df['knn_dist'] = knn_dist

# Inverse distances
knn_df['knn_dist_inverse'] = 1/knn_df['knn_dist']

# Normalise the inverse values between 0 and 1
# First drop user input row
knn_df.drop([0], inplace=True)
knn_df.reset_index(inplace=True, drop=True)
# Normalise pw_dist_inverse column
knn_normalised = knn_df['knn_dist_inverse']/ceil(max(knn_df['knn_dist_inverse']))
knn_df['knn_normalised'] = knn_normalised

# %% [markdown]
# Plot nearest neighbour results

# %%
# Get top 10 most similar suburbs in PCA dataframe
knn_df_sort = knn_df.sort_values(by=['knn_normalised'], ascending=False)
top_10 = knn_df_sort[:10]

knn_df_sort.head(10)
# Out:
#      Suburb_id           Suburb  Postcode  \
# 222        784    Englorie Park    2560.0
# 489       1863      Point Piper    2027.0
# 21          97          Austral    2179.0
# 167        604     Croydon Park    2133.0
# 55         211         Berrilee    2159.0
# 617       2409  Wentworth Point    2127.0
# 269        986    Gregory Hills    2557.0
# 392       1478            Menai    2234.0
# 303       1137       Hurstville    2220.0
# 375       1402  Macquarie Links    2565.0
#
#                                                    LGA    City        PC1  \
# 222                              City of Campbelltown   Sydney  28.918363
# 489                          Municipality of Woollahra  Sydney  28.919677
# 21                                  City of Liverpool   Sydney  28.923073
# 167  Canterbury-Bankstown Council, Burwood Council,...  Sydney  28.923444
# 55                                       Hornsby Shire  Sydney  28.923667
# 617                                 City of Parramatta  Sydney  28.924726
# 269                                    Camden Council   Sydney  28.925969
# 392                                   Sutherland Shire  Sydney  28.929283
# 303                              Georges River Council  Sydney  28.929591
# 375                              City of Campbelltown   Sydney  29.929745
#
#           PC2  knn_dist  knn_dist_inverse  knn_normalised
# 222  2.043938  0.055175         18.124286        0.953910
# 489  1.569268  0.529846          1.887340        0.099334
# 21   0.668933  1.430188          0.699209        0.036800
# 167  0.651865  1.447256          0.690963        0.036366
# 55   0.499648  1.599474          0.625206        0.032906
# 617  0.155115  1.944008          0.514401        0.027074
# 269 -0.014846  2.113973          0.473043        0.024897
# 392 -0.998972  3.098104          0.322778        0.016988
# 303 -1.204718  3.303849          0.302677        0.015930
# 375 -1.253018  3.501413          0.285599        0.015032

# %%
# Plot the top 10 KNN Sydney suburbs of South Yarra, Melbourne
input_x = input_suburb_df.area.values[0]
input_y = input_suburb_df.distance.values[0]
plt.figure(figsize=(14,14))
plt.scatter(knn_df.area, knn_df.distance)
plt.scatter(top_10.area, top_10.distance, c='orange')
plt.scatter(input_x, input_y, c='red')
plt.title('Figure 2: KNN with Sydney suburbs and South Yarra, Melbourne')
plt.xlabel('Area')
plt.ylabel('Distance')
# plt.xlim(0.5,2)
# plt.ylim(2,2.6)
# Label input suburb
plt.annotate(input_suburb['Suburb'], (input_x, input_y), size=15)
# Label top 10 suburbs
for area, dist, txt in zip(top_10.area, top_10.distance, [*top_10.Suburb]):
    plt.annotate(txt, (area, dist), size=15)

# %% [markdown]
# # Demographic Analysis

# %%
# Extract area, density, and distance columns to be transformed and standardised
demographic_data = temp_data[['density', 'median_age', 'family_percentage']]

# # Yeo-Johnson transformation
# # Create the Scaler object
# scaler = preprocessing.PowerTransformer(method='yeo-johnson', standardize=False)

# # Fit your data on the scaler object
# yeojohnson = scaler.fit_transform(demographic_data)

# suburbs_info_yeojohnson = pd.DataFrame(yeojohnson, columns=demographic_data.columns)

# # Matrix standardisation
# # Create the Scaler object
# scaler = preprocessing.MinMaxScaler()

# # Fit your data on the scaler object
# standardised = scaler.fit_transform(demographic_data)

# standardised = pd.DataFrame(standardised, columns=demographic_data.columns)

# # Add suburb and postcode labels to rows
# demographic_df = standardised
# demographic_df.insert(0, 'Suburb_id', aus_suburbs.Suburb_id)
# demographic_df.insert(1, 'Suburb', aus_suburbs.Suburb)
# demographic_df.insert(2, 'Postcode', aus_suburbs.Postcode)
# demographic_df.insert(3, 'LGA', aus_suburbs.LGA)
# demographic_df.insert(4, 'City', aus_suburbs.City)

# %%
plt.hist(np.log(demographic_data.density.values))
# Out:
# (array([   4.,   11.,   22.,  101.,  151.,  218.,  204.,  686., 1049.,
#           88.]),
#  array([-2.73783551, -1.46665314, -0.19547077,  1.0757116 ,  2.34689397,
#          3.61807634,  4.88925872,  6.16044109,  7.43162346,  8.70280583,
#          9.9739882 ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.sqrt(demographic_data.median_age.values))
# Out:
# (array([   3.,    2.,   25.,  342., 1067.,  906.,  143.,   36.,    8.,
#            2.]),
#  array([3.46410162, 4.03420659, 4.60431157, 5.17441655, 5.74452153,
#         6.3146265 , 6.88473148, 7.45483646, 8.02494143, 8.59504641,
#         9.16515139]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.sqrt(demographic_data.median_rent.values))
# Out:
# (array([1.200e+01, 2.000e+00, 9.000e+00, 1.190e+02, 1.228e+03, 9.430e+02,
#         1.840e+02, 2.700e+01, 9.000e+00, 1.000e+00]),
#  array([ 0.        ,  3.87298335,  7.74596669, 11.61895004, 15.49193338,
#         19.36491673, 23.23790008, 27.11088342, 30.98386677, 34.85685012,
#         38.72983346]),
#  <a list of 10 Patch objects>)

# %%
demographic_df
# Out:
#       Suburb_id             Suburb  Postcode  \
# 0             0         Abbotsbury    2176.0
# 1             1         Abbotsford    2046.0
# 2             2         Abbotsford    3067.0
# 3             3         Aberfeldie    3040.0
# 4             4     Aberfoyle Park    5159.0
# 5             5     Acacia Gardens    2763.0
# 6             6       Acacia Hills     822.0
# 7             7       Acacia Ridge    4110.0
# 8             8              Acton    2601.0
# 9             9         Acton Park    7170.0
# 10           10   Adelaide Airport    5950.0
# 11           11        Agnes Banks    2753.0
# 12           12            Ainslie    2602.0
# 13           13              Airds    2560.0
# 14           14       Airport West    3042.0
# 15           15              Alawa     810.0
# 16           16          Albanvale    3021.0
# 17           17       Albany Creek    4035.0
# 18           18        Albert Park    5014.0
# 19           19        Albert Park    3206.0
# 20           20           Alberton    5014.0
# 21           21             Albion    4010.0
# 22           22             Albion    3020.0
# 23           23           Alderley    4051.0
# 24           24            Aldinga    5173.0
# 25           25      Aldinga Beach    5173.0
# 26           26  Alexander Heights    6064.0
# 27           27    Alexandra Hills    4161.0
# 28           28         Alexandria    2015.0
# 29           29      Alfords Point    2234.0
# ...         ...                ...       ...
# 2505       2505          Woodville    5011.0
# 2506       2506  Woodville Gardens    5012.0
# 2507       2507    Woodville North    5012.0
# 2508       2508     Woodville Park    5011.0
# 2509       2509    Woodville South    5011.0
# 2510       2510     Woodville West    5011.0
# 2511       2511        Woody Point    4019.0
# 2512       2512          Woollahra    2025.0
# 2513       2513      Woolloomooloo    2011.0
# 2514       2514            Woolner     820.0
# 2515       2515         Woolooware    2230.0
# 2516       2516          Wooloowin    4030.0
# 2517       2517           Woolshed    4340.0
# 2518       2518           Woolwich    2110.0
# 2519       2519      Woori Yallock    3139.0
# 2520       2520             Woorim    4507.0
# 2521       2521           Wooroloo    6558.0
# 2522       2522           Woronora    2232.0
# 2523       2523   Woronora Heights    2233.0
# 2524       2524             Wright    2611.0
# 2525       2525             Wulagi     812.0
# 2526       2526          Wulkuraka    4305.0
# 2527       2527            Wungong    6112.0
# 2528       2528       Wyndham Vale    3024.0
# 2529       2529          Wynn Vale    5127.0
# 2530       2530             Wynnum    4178.0
# 2531       2531        Wynnum West    4178.0
# 2532       2532            Yagoona    2199.0
# 2533       2533          Yallambie    3085.0
# 2534       2534            Yamanto    4305.0
#
#                                                  LGA       City   density  \
# 0                                  City of Fairfield     Sydney  0.041004
# 1                                 City of Canada Bay     Sydney  0.251873
# 2                                      City of Yarra  Melbourne  0.208727
# 3                              City of Moonee Valley  Melbourne  0.113350
# 4                                City of Onkaparinga   Adelaide  0.089039
# 5                                  City of Blacktown     Sydney  0.184925
# 6                            Litchfield Municipality     Darwin  0.000305
# 7                    City of Brisbane, Moorooka Ward   Brisbane  0.043996
# 8                                     North Canberra   Canberra  0.019168
# 9                                   City of Clarence     Hobart  0.004566
# 10                              City of West Torrens   Adelaide  0.002700
# 11               City of Hawkesbury, City of Penrith     Sydney  0.069579
# 12                                    North Canberra   Canberra  0.057943
# 13                             City of Campbelltown      Sydney  0.088445
# 14                             City of Moonee Valley  Melbourne  0.089612
# 15                                    City of Darwin     Darwin  0.134948
# 16                                  City of Brimbank  Melbourne  0.083355
# 17                                Moreton Bay Region   Brisbane  0.089357
# 18                             City of Charles Sturt   Adelaide  0.099620
# 19                              City of Port Phillip  Melbourne  0.092582
# 20                     City of Port Adelaide Enfield   Adelaide  0.086139
# 21                  Hamilton Ward , City of Brisbane   Brisbane  0.086893
# 22                                  City of Brimbank  Melbourne  0.123283
# 23    City of Brisbane, Enoggera Ward, Marchant Ward   Brisbane  0.002021
# 24                               City of Onkaparinga   Adelaide  0.041410
# 25                               City of Onkaparinga   Adelaide  0.117869
# 26                                  City of Wanneroo      Perth  0.062402
# 27                                      Redland City   Brisbane  0.112075
# 28                                    City of Sydney     Sydney  0.046928
# 29                                  Sutherland Shire     Sydney  0.089689
# ...                                              ...        ...       ...
# 2505                           City of Charles Sturt   Adelaide  0.107380
# 2506                   City of Port Adelaide Enfield   Adelaide  0.186644
# 2507                           City of Charles Sturt   Adelaide  0.066128
# 2508                           City of Charles Sturt   Adelaide  0.033470
# 2509                           City of Charles Sturt   Adelaide  0.000356
# 2510                           City of Charles Sturt   Adelaide  0.060968
# 2511                              Moreton Bay Region   Brisbane  0.000297
# 2512                       Municipality of Woollahra     Sydney  0.003727
# 2513                                  City of Sydney     Sydney  0.006610
# 2514                                  City of Darwin     Darwin  0.013558
# 2515                                Sutherland Shire     Sydney  0.015422
# 2516                Hamilton Ward , City of Brisbane   Brisbane  0.004700
# 2517                                 City of Ipswich   Brisbane  0.001284
# 2518                   Municipality of Hunter's Hill     Sydney  0.119958
# 2519                           Shire of Yarra Ranges  Melbourne  0.107739
# 2520                              Moreton Bay Region   Brisbane  0.001246
# 2521                              Shire of Mundaring      Perth  0.006523
# 2522                                Sutherland Shire     Sydney  0.000513
# 2523                                Sutherland Shire     Sydney  0.051378
# 2524                                 Molonglo Valley   Canberra  0.000559
# 2525                                  City of Darwin     Darwin  0.028473
# 2526                                 City of Ipswich   Brisbane  0.000233
# 2527                                City of Armadale      Perth  0.095487
# 2528                                 City of Wyndham  Melbourne  0.108164
# 2529                          City of Tea Tree Gully   Adelaide  0.083373
# 2530             Wynnum Manly Ward, City of Brisbane   Brisbane  0.004042
# 2531             Wynnum Manly Ward, City of Brisbane   Brisbane  0.000714
# 2532                    Canterbury-Bankstown Council     Sydney  0.597453
# 2533                                 City of Banyule  Melbourne  0.128405
# 2534                                 City of Ipswich   Brisbane  0.017299
#
#       median_age  median_rent
# 0       0.361111     0.336667
# 1       0.458333     0.346667
# 2       0.277778     0.284000
# 3       0.388889     0.234000
# 4       0.388889     0.213333
# 5       0.305556     0.346667
# 6       0.347222     0.236667
# 7       0.305556     0.213333
# 8       0.111111     0.253267
# 9       0.430556     0.183333
# 10      0.333333     0.253333
# 11      0.402778     0.183333
# 12      0.250000     0.118667
# 13      0.388889     0.233333
# 14      0.333333     0.253333
# 15      0.333333     0.200000
# 16      0.388889     0.266667
# 17      0.375000     0.171333
# 18      0.430556     0.333333
# 19      0.444444     0.166667
# 20      0.277778     0.253333
# 21      0.291667     0.169333
# 22      0.291667     0.246667
# 23      0.472222     0.166667
# 24      0.319444     0.200000
# 25      0.347222     0.260000
# 26      0.347222     0.250000
# 27      0.291667     0.393333
# 28      0.388889     0.493333
# 29      0.375000     0.295333
# ...          ...          ...
# 2505    0.375000     0.266667
# 2506    0.305556     0.253333
# 2507    0.319444     0.213333
# 2508    0.277778     0.206667
# 2509    0.486111     0.133333
# 2510    0.319444     0.233333
# 2511    0.416667     0.102000
# 2512    0.361111     0.210667
# 2513    0.444444     0.180000
# 2514    0.180556     0.260000
# 2515    0.513889     0.300000
# 2516    0.430556     0.256667
# 2517    0.333333     0.366667
# 2518    0.333333     0.266667
# 2519    0.388889     0.366667
# 2520    0.555556     0.261267
# 2521    0.472222     0.218667
# 2522    0.472222     0.172000
# 2523    0.277778     0.240000
# 2524    0.458333     0.193333
# 2525    0.388889     0.116667
# 2526    0.458333     0.223867
# 2527    0.333333     0.240667
# 2528    0.347222     0.226667
# 2529    0.444444     0.456667
# 2530    0.416667     0.266667
# 2531    0.569444     0.146000
# 2532    0.222222     0.433333
# 2533    0.291667     0.226667
# 2534    0.208333     0.366667
#
# [2535 rows x 8 columns]

# %% [markdown]
# # Demographic PCA

# %%
data = demographic_df.drop(columns=['Suburb_id', 'Suburb', 'Postcode', 'LGA', 'City'], axis=1)

pca = PCA()
pca.fit(data)
pca_data = pca.transform(data)

percentage_variation = np.round(pca.explained_variance_ratio_ * 100, decimals=1)
labels = ['PC' + str(x) for x in range(1, len(percentage_variation)+1)]

plt.bar(x=range(1,len(percentage_variation)+1), height=percentage_variation, tick_label=labels)
plt.ylabel('Percentage of Explained Variance')
plt.xlabel('Principal Component')
plt.title('Figure 1: Scree Plot')
plt.show()

# %%
print('PC1: {}'.format(pca.explained_variance_ratio_[0]))
print('PC2: {}'.format(pca.explained_variance_ratio_[1]))
print('PC3: {}'.format(pca.explained_variance_ratio_[2]))
# Out:
# PC1: 0.4876859475335142
# PC2: 0.3076852860330881
# PC3: 0.2046287664333978

# %%
0.47601914379057136+0.32010108115503555
# Out:
# 0.796120224945607

# %% [markdown]
# PC1, PC2, and PC3 accounts for 86% of the total variation around the PCs.

# %%
pca_df = pd.DataFrame(pca_data, columns=labels)

plt.figure(figsize=(10,10))
plt.scatter(pca_df.PC1, pca_df.PC2)
plt.title(' Figure 2: PCA graph')
plt.xlabel('PC1 = {}%'.format(percentage_variation[0]))
plt.ylabel('PC2 = {}%'.format(percentage_variation[1]))
# plt.xlim(-5,5)
# plt.ylim(-5,5)
# Out:
# Text(0, 0.5, 'PC2 = 30.8%')

# %% [markdown]
# Furthermore, appears that the list of suburbs can be roughly divided into two or three clusters. This will be further analysed in another notebook.

# %%
# The normalised variance of each attribute for all three principle components.
pd.DataFrame(pca.components_,columns=data.columns,index = ['PC1','PC2','PC3'])
# Out:
#       density  median_age  median_rent
# PC1  0.730321   -0.560180     0.390935
# PC2  0.198517    0.721639     0.663196
# PC3  0.653623    0.406738    -0.638233

# %% [markdown]
# In addition to PC1 having the most variation in regards to suburb area, density, and distance, all three attribuates for PC1 had roughly an equal influence on the distribution of the data. However, suburb area and density had a slight larger influence.

# %%
# Add suburb and postcode labels to rows
demographic_df = pca_df
demographic_df.insert(0, 'Suburb_id', aus_suburbs.Suburb_id)
demographic_df.insert(1, 'Suburb', aus_suburbs.Suburb)
demographic_df.insert(2, 'Postcode', aus_suburbs.Postcode)
demographic_df.insert(3, 'LGA', aus_suburbs.LGA)
demographic_df.insert(4, 'City', aus_suburbs.City)

# Drop PC3 column
demographic_df.drop(columns='PC3', axis=1, inplace=True)

# %% [markdown]
# # Demographic KNN

# %%
# Input data
input_suburb_df = demographic_df.loc[(demographic_df.Suburb == input_suburb['Suburb']) &
                              (demographic_df.City == input_suburb['City'])]
input_city_df = demographic_df.loc[demographic_df.City == input_city]

# Dataframe for pairwise calculation
knn_df = pd.concat([input_suburb_df, input_city_df], ignore_index=True)

# Convert dataframe to array
values_df = knn_df.drop(['Suburb_id', 'Suburb', 'City', 'Postcode', 'LGA'], axis=1)
values_array = values_df.values

# Pairwise calculation
D = distance.squareform(distance.pdist(values_array))
D = D[0]

# Convert pairwise distances to dataframe
knn_dist = pd.DataFrame(data=D.flatten())

# Add distances to full geographic dataframe
knn_df['knn_dist'] = knn_dist

# Inverse distances
knn_df['knn_dist_inverse'] = 1/knn_df['knn_dist']

# Normalise the inverse values between 0 and 1
# First drop user input row
knn_df.drop([0], inplace=True)
knn_df.reset_index(inplace=True, drop=True)
# Normalise pw_dist_inverse column
knn_normalised = knn_df['knn_dist_inverse']/ceil(max(knn_df['knn_dist_inverse']))
knn_df['knn_normalised'] = knn_normalised

# %%
# Get top 10 most similar suburbs in PCA dataframe
knn_df_sort = knn_df.sort_values(by=['knn_normalised'], ascending=False)
top_10 = knn_df_sort[:10]

knn_df_sort.head(10)
# Out:
#      Suburb_id             Suburb  Postcode  \
# 486       1853  Pitt Town Bottoms    2756.0
# 224        788             Epping    2121.0
# 230        815          Fairfield    2165.0
# 543       2037         Scheyville    2756.0
# 469       1779    Padstow Heights    2211.0
# 303       1137         Hurstville    2220.0
# 151        547            Concord    2137.0
# 251        926        Glendenning    2761.0
# 118        434         Castlecrag    2068.0
# 229        806           Eveleigh    2015.0
#
#                                        LGA    City       PC1       PC2  \
# 486                     City of Hawkesbury  Sydney  0.080370 -0.022792
# 224                     City of Parramatta  Sydney  0.072936 -0.027729
# 230  City of Fairfield, Cumberland Council  Sydney  0.091360 -0.023517
# 543                     City of Hawkesbury  Sydney  0.093154 -0.026459
# 469           Canterbury-Bankstown Council  Sydney  0.089470 -0.016322
# 303                  Georges River Council  Sydney  0.072582 -0.016201
# 151                     City of Canada Bay  Sydney  0.073688 -0.014901
# 251                      City of Blacktown  Sydney  0.093256 -0.032142
# 118                     City of Willoughby  Sydney  0.066528 -0.026271
# 229                         City of Sydney  Sydney  0.095239 -0.020181
#
#      knn_dist  knn_dist_inverse  knn_normalised
# 486  0.003310        302.136133        0.997149
# 224  0.008458        118.235024        0.390215
# 230  0.010444         95.749541        0.316005
# 543  0.011950         83.685147        0.276189
# 469  0.012715         78.646892        0.259561
# 303  0.013053         76.612651        0.252847
# 151  0.013403         74.609376        0.246236
# 251  0.013522         73.953616        0.244071
# 118  0.014688         68.082039        0.224693
# 229  0.015181         65.869646        0.217392

# %% [markdown]
# #### 3. K Nearest Neighbour

# %% [markdown]
# Here I implement **KNN pairwise by distance** to find the most similar suburbs from the user input in regards to population density, suburb size, and  distance from cbd. I will implement KNN with the PCA transformed data.

# %%
# Input data
input_suburb_df = geo_df.loc[(geo_df.Suburb == input_suburb['Suburb']) &
                              (geo_df.City == input_suburb['City'])]
input_city_df = geo_df.loc[geo_df.City == input_city]

# Dataframe for pairwise calculation
knn_df = pd.concat([input_suburb_df, input_city_df], ignore_index=True)

# Convert dataframe to array
values_df = knn_df.drop(['Suburb_id', 'Suburb', 'City', 'Postcode', 'LGA'], axis=1)
values_array = values_df.values

# Pairwise calculation
D = distance.squareform(distance.pdist(values_array))
D = D[0]

# Convert pairwise distances to dataframe
knn_dist = pd.DataFrame(data=D.flatten())

# Add distances to full geographic dataframe
knn_df['knn_dist'] = knn_dist

# Inverse distances
knn_df['knn_dist_inverse'] = 1/knn_df['knn_dist']

# Normalise the inverse values between 0 and 1
# First drop user input row
knn_df.drop([0], inplace=True)
knn_df.reset_index(inplace=True, drop=True)
# Normalise pw_dist_inverse column
knn_normalised = knn_df['knn_dist_inverse']/ceil(max(knn_df['knn_dist_inverse']))
knn_df['knn_normalised'] = knn_normalised

# %% [markdown]
# #### 4. Plot user input and listed suburbs on PCA scatterplot

# %%
# Get top 10 most similar suburbs in PCA dataframe
knn_df_sort = knn_df.sort_values(by=['knn_normalised'], ascending=False)
top_10 = knn_df_sort[:10]

# %%
input_x = input_suburb_df.PC1.values[0]
input_y = input_suburb_df.PC2.values[0]
plt.figure(figsize=(14,14))
plt.scatter(knn_df.PC1, knn_df.PC2)
plt.scatter(top_10.PC1, top_10.PC2, c='orange')
plt.scatter(input_x, input_y, c='red')
plt.title('Figure 3: PCA graph with Top suburbs')
plt.xlabel('PC1 = {}%'.format(percentage_variation[0]))
plt.ylabel('PC2 = {}%'.format(percentage_variation[1]))
plt.xlim(1.5,2.5)
plt.ylim(0,1)
# Label input suburb
plt.annotate(input_suburb['Suburb'], (input_x, input_y), size=15)
# Label top 10 suburbs
for pc1, pc2, txt in zip(top_10.PC1, top_10.PC2, [*top_10.Suburb]):
    plt.annotate(txt, (pc1, pc2), size=15)

# %% [markdown]
# Get top ten most similar suburbs in Australian suburbs dataset.

# %%
# Add knn normalised values to new dataframe
top_ten_knn = aus_suburbs[['Suburb', 'Postcode', 'LGA', 'City', 'area', 'density', 'distance']]
top_ten_knn = top_ten_knn.loc[top_ten_knn.City == input_city]
top_ten_knn.reset_index(inplace=True, drop=True)

# top_ten_knn.reset_index(inplace=True, drop=True)
top_ten_knn['knn_normalised'] = knn_normalised

# Sort suburbs by their knn_normalised values in descending order.
top_ten_knn.sort_values(by=['knn_normalised'], ascending=False, inplace=True)
top_ten_knn.reset_index(inplace=True, drop=True)

# Get top 10 suburbs
top_ten_knn = top_ten_knn[:10]
top_ten_knn
# Out:
#           Suburb  Postcode                            LGA    City   area  \
# 0       Woolwich      2110  Municipality of Hunter's Hill  Sydney  0.480
# 1     Kensington      2033               City of Randwick  Sydney  2.585
# 2  Bellevue Hill      2023      Municipality of Woollahra  Sydney  2.310
# 3      Greenwich      2065      Municipality of Lane Cove  Sydney  1.601
# 4     Leichhardt      2040             Inner West Council  Sydney  2.520
# 5        Rozelle      2039             Inner West Council  Sydney  1.723
# 6      Lilyfield      2040             Inner West Council  Sydney  2.144
# 7    Longueville      2066      Municipality of Lane Cove  Sydney  0.949
# 8      Drummoyne      2047             City of Canada Bay  Sydney  2.192
# 9       Cammeray      2062           North Sydney Council  Sydney  1.514
#
#        density  distance  knn_normalised
# 0  1695.833333  4.754440        0.985048
# 1  5804.255319  4.444528        0.223085
# 2  4638.961039  4.503572        0.222268
# 3  3505.933791  4.743348        0.217964
# 4  5803.571429  4.860991        0.146714
# 5  5063.842136  3.138417        0.130479
# 6  3552.238806  3.956786        0.122956
# 7  2170.706006  5.741948        0.122549
# 8  5451.642336  5.261509        0.116186
# 9  4627.476882  5.331783        0.114636

# %% [markdown]
# #### 5. Plot average area, density, and distance against the user inputs suburb in a bar chart

# %%
# Input data
input_index = aus_suburbs.loc[aus_suburbs.Suburb == input_suburb['Suburb']].index.values[0]
input_area = aus_suburbs.at[input_index, 'area']
input_density = aus_suburbs.at[input_index, 'density']
input_distance = aus_suburbs.at[input_index, 'distance']

# Calculate average
area_mean = np.mean(top_ten_knn.area.values)
density_mean = np.mean(top_ten_knn.density.values)
distance_mean = np.mean(top_ten_knn.distance.values)

# Calculate standard deviation
area_std = np.std(top_ten_knn.area.values)
density_std = np.std(top_ten_knn.density.values)
distance_std = np.std(top_ten_knn.distance.values)

# Subplot
# Create lists for the plot
mean_list = [area_mean,
             density_mean,
             distance_mean]
input_mean = [input_area,
              input_density,
              input_distance]
error_data = [area_std,
              density_std,
              distance_std]
chart_coordinates = [(0,0),
                     (0,1),
                     (1,0)]
y_labels = ['Avg size ($km^2$)',
            'Average Density ($pp/km^2$)',
            'Distance to CBD (km)']
titles = ['Suburb Size',
          'Population Density',
          'Distance to CBD']

category = [input_suburb['Suburb'],
            'Top 10 suburbs']
x_pos = np.arange(len(category))

# Build the plot
fig, ax = plt.subplots(2, 2, figsize=(11,11))
fig.suptitle('Figure 4: Comparison between South Yarra and Top 10 Sydney Suburbs')
for user_input, mean, error, coord, ylabel, title in zip(input_mean,
                                                         mean_list, 
                                                         error_data,
                                                         chart_coordinates,
                                                         y_labels,
                                                         titles):
    ax[coord].bar(x_pos,
                  [user_input, mean],
                  yerr=[0, error],
                  align='center',
                  alpha=1,
                  color=('steelblue', 'coral'),
                  capsize=10)
    ax[coord].set_ylabel(ylabel)
    ax[coord].set_xticks(x_pos)
    ax[coord].set_xticklabels(category)
    ax[coord].set_title(title, y=1.01)
    ax[coord].yaxis.grid(True)


# Delete empty axes
fig.delaxes(ax[1][1])
plt.show()

# %% [markdown]
# # Local venues - Dot Product

# %% [markdown]
# #### 1. Normalise data with MinMaxScaler

# %%
# Drop label columns to standardise hot-encoded columns
temp_data = venues_grouped.drop(['Suburb_id', 'Suburb', 'Postcode', 'LGA', 'City'], axis=1)

# Matrix standardisation
# Create the Scaler object
scaler = preprocessing.MinMaxScaler()

# Fit your data on the scaler object
standardised = scaler.fit_transform(temp_data)

standardised = pd.DataFrame(standardised, columns=temp_data.columns)


# Add suburb and postcode columns
venue_df = standardised
venue_df.insert(0, 'Suburb_id', venues_grouped.Suburb_id)
venue_df.insert(1, 'Suburb', venues_grouped.Suburb)
venue_df.insert(2, 'Postcode', venues_grouped.Postcode)
venue_df.insert(3, 'City', venues_grouped.City)

# venue_df = venues_grouped.drop(['LGA'], axis=1)
# Out:
# /Users/Jason/anaconda3/lib/python3.7/site-packages/sklearn/preprocessing/data.py:334: DataConversionWarning: Data with input dtype int64 were all converted to float64 by MinMaxScaler.
#   return self.partial_fit(X, y)

# %% [markdown]
# #### 2. Dot product
# Here I implement **dot product valuation** to find the most similar suburbs in regard to its local venues.

# %%
# Input data
input_suburb_ven = venue_df.loc[(venue_df.Suburb == input_suburb['Suburb']) &
                                (venue_df.City == input_suburb['City'])]

input_city_ven = venue_df.loc[venue_df.City == input_city]

# Add input_suburb to city dataframe
dot_df = pd.concat([input_suburb_ven, input_city_ven], ignore_index=True)

# Convert dataframe to array
input_profile = input_suburb_ven.drop(['Suburb_id', 'Suburb', 'Postcode', 'City'], axis=1)
input_profile = input_profile.values
values_df = dot_df.drop(['Suburb_id', 'Suburb', 'Postcode', 'City'], axis=1)
values_array = values_df.values

# Dot product calculation
dot_product = (values_array).dot(input_profile[0])

# Convert dot product arrays to dataframe
dot_product_df = pd.DataFrame(data=dot_product.flatten())

# Add dot product values to full venues dataframe
dot_df['dot_product'] = dot_product_df

# Normalise the dot product between 0 and 1
# Drop user input row
dot_df.drop([0], inplace=True)
dot_df.reset_index(inplace=True, drop=True)
# Normalise dot_product column
dot_normalised = dot_df['dot_product']/ceil(max(dot_df['dot_product']))
dot_df['dot_normalised'] = dot_normalised

# Sort rows and get top 10 suburbs
dot_df.sort_values(by=['dot_normalised'], ascending=False, inplace=True)
dot_df.reset_index(inplace=True, drop=True)
top_ten_dot = dot_df[:10]

# %% [markdown]
# The top ten suburbs that have the most similar local venues to the input suburb

# %%
top_ten_dot[['Suburb_id', 'Suburb', 'Postcode', 'dot_product', 'dot_normalised']]
# Out:
#    Suburb_id         Suburb  Postcode  dot_product  dot_normalised
# 0        467     Parramatta      2150     4.926406        0.985281
# 1        634  Woolloomooloo      2011     4.734381        0.946876
# 2        565    Surry Hills      2010     4.420148        0.884030
# 3        163     Crows Nest      2065     4.077030        0.815406
# 4        155         Coogee      2034     3.728331        0.745666
# 5        578      The Rocks      2000     3.684622        0.736924
# 6        442   North Sydney      2060     3.096983        0.619397
# 7         31      Bankstown      2200     3.075751        0.615150
# 8        650        Norwest      2153     3.045499        0.609100
# 9        489        Pyrmont      2009     3.042416        0.608483

# %% [markdown]
# Show the top ten suburbs in regards to most similar venues and their venues ranked from the most to least common. User input row is included for comparison.

# %% [markdown]
# #### 3. Plot top 10 most common local venues for each suburb

# %%
top_venues = venues_sorted.drop(['Suburb_id', 'City'], axis=1)
top_venues = top_venues.iloc[top_ten_dot.Suburb_id.values]

# Add input suburb to compare its local venues
input_suburb_venue = venues_sorted.loc[(venues_sorted.Suburb == input_suburb['Suburb']) &
                                           (venues_sorted.City == input_suburb['City'])]

input_suburb_venue = input_suburb_venue.drop(['Suburb_id', 'City'], axis=1)
input_suburb_venue
top_venues = pd.concat([input_suburb_venue, top_venues], ignore_index=True)

top_venues
# Out:
#            Suburb  Postcode                                     LGA  \
# 0     South Yarra      3141  City of Stonnington, City of Melbourne
# 1      Parramatta      2150                      City of Parramatta
# 2   Woolloomooloo      2011                          City of Sydney
# 3     Surry Hills      2010                          City of Sydney
# 4      Crows Nest      2065                    North Sydney Council
# 5          Coogee      2034                        City of Randwick
# 6       The Rocks      2000                          City of Sydney
# 7    North Sydney      2060                    North Sydney Council
# 8       Bankstown      2200            Canterbury-Bankstown Council
# 9         Norwest      2153                         The Hills Shire
# 10        Pyrmont      2009                          City of Sydney
#
#     1st Most Common Venue 2nd Most Common Venue  3rd Most Common Venue  \
# 0                    Café    Italian Restaurant    Japanese Restaurant
# 1                    Café       Thai Restaurant           Burger Joint
# 2                    Café    Italian Restaurant                  Hotel
# 3                    Café                   Pub            Pizza Place
# 4                    Café   Japanese Restaurant        Thai Restaurant
# 5                    Café                 Hotel           Burger Joint
# 6                    Café                 Hotel  Australian Restaurant
# 7                    Café                   Gym    Japanese Restaurant
# 8   Vietnamese Restaurant                  Café      Convenience Store
# 9                    Café        Sandwich Place                  Hotel
# 10                   Café                   Bar  Australian Restaurant
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0                   Hotel     Convenience Store       Thai Restaurant
# 1      Chinese Restaurant    Mexican Restaurant          Dessert Shop
# 2   Australian Restaurant       Thai Restaurant                Hostel
# 3     Japanese Restaurant        Breakfast Spot   Lebanese Restaurant
# 4   Vietnamese Restaurant    Italian Restaurant     Indian Restaurant
# 5                     Bar                  Park       Thai Restaurant
# 6                     Pub             Hotel Bar    Italian Restaurant
# 7                     Bar             Juice Bar        Sandwich Place
# 8    Fast Food Restaurant            Sports Bar      Department Store
# 9             Supermarket  Gym / Fitness Center    Mexican Restaurant
# 10         Breakfast Spot     French Restaurant   Japanese Restaurant
#
#     7th Most Common Venue  8th Most Common Venue 9th Most Common Venue  \
# 0                     Bar          Grocery Store          Dessert Shop
# 1               Juice Bar       Asian Restaurant   Japanese Restaurant
# 2      Chinese Restaurant                    Pub                   Bar
# 3   Vietnamese Restaurant        Thai Restaurant           Karaoke Bar
# 4                     Bar         Sandwich Place    Mexican Restaurant
# 5       Fish & Chips Shop      Indian Restaurant    Italian Restaurant
# 6              Steakhouse                   Park          Cocktail Bar
# 7                  Bakery  Vietnamese Restaurant                 Plaza
# 8              Steakhouse    Lebanese Restaurant                   Gym
# 9             Pizza Place             Restaurant          Liquor Store
# 10                    Pub             Restaurant                  Park
#
#    10th Most Common Venue
# 0       French Restaurant
# 1      Italian Restaurant
# 2              Restaurant
# 3       Indian Restaurant
# 4        Asian Restaurant
# 5        Sushi Restaurant
# 6          Scenic Lookout
# 7           Grocery Store
# 8           Grocery Store
# 9           Train Station
# 10    Dumpling Restaurant

# %% [markdown]
# #### 4. Plot the most common venues among the similar suburbs

# %%
# List all of the venues in the dataframe
venues = top_venues.drop(['Suburb', 'Postcode', 'LGA'], axis=1)
venues = pd.DataFrame(data=venues.values.flatten())
venues = venues.dropna()
venues.rename(columns={0: "Venues"}, inplace=True)

# Group dataframe by venue and show its frequency count
venues_count = venues.groupby(['Venues']).agg({'Venues' :'count'})
venues_count.rename(columns={'Venues': 'Venues', 'Venues': 'Frequency'}, inplace=True)
venues_count.sort_values(by=['Frequency'], inplace=True, ascending=False)

# %%
# Create lists for the plot
materials = venues_count.index
y_pos = np.arange(len(materials))
values = venues_count.values.flatten()

unique_values = list(np.unique(values))
unique_values.sort(reverse=True)

bar_colours = ['tab:blue',
               'tab:orange',
               'tab:green',
               'tab:red',
               'tab:purple',
               'tab:cyan',
               'tab:brown',
               'tab:pink',
               'tab:gray',
               'tab:olive']
bar_colours_range = bar_colours[0:len(unique_values)]

# Build the plot
fig = plt.figure(figsize=(15,15))
for val, colour in zip(unique_values, bar_colours_range):
    mask = values == val
    plt.barh(y_pos[mask], values[mask], color=colour, align='center')
plt.xlabel('Count')
plt.yticks(y_pos, materials)
plt.title('Figure 5: Venue Count', y=1.01)
plt.gca().invert_yaxis()
plt.grid(axis='x')

# %% [markdown]
# # Find the overall most similar suburb using Naive Bayes.

# %% [markdown]
# Here I combine the findings from above and implement Naive Bayes to find the most similar suburb.
#
# Pior probability will be set to 0.5, which means both the geographic/demographic and local venues will have an equal contribution to the final probability value (posterior probability).

# %%
# Combine pairwise distances and cosine similarity dataframes
top_suburbs = knn_df[['Suburb_id', 'Suburb', 'Postcode', 'LGA']]

top_suburbs.loc[:,'knn_normalised'] = knn_normalised
top_suburbs.loc[:,'dot_normalised'] = dot_normalised

# Calculate final valuation metric by finding the by product between the knn and dot product columns
top_suburbs.loc[:,'final_score'] = (knn_normalised*0.75) + (dot_normalised*0.25)

# Sort suburbs by Degree_of_similarity in descending order.
top_suburbs.sort_values(by=['final_score'], ascending=False, inplace=True)
top_suburbs.reset_index(inplace=True, drop=True)

# Get top n suburbs
top_n = 10
top_suburbs = top_suburbs[:top_n]
# Out:
# /Users/Jason/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:362: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[key] = _infer_fill_value(value)
# /Users/Jason/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# /Users/Jason/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()

# %%
top_suburbs
# Out:
#    Suburb_id         Suburb  Postcode                            LGA  \
# 0        636       Woolwich      2110  Municipality of Hunter's Hill
# 1        467     Parramatta      2150             City of Parramatta
# 2        634  Woolloomooloo      2011                 City of Sydney
# 3        565    Surry Hills      2010                 City of Sydney
# 4        163     Crows Nest      2065           North Sydney Council
# 5        155         Coogee      2034               City of Randwick
# 6        578      The Rocks      2000                 City of Sydney
# 7        442   North Sydney      2060           North Sydney Council
# 8        425    Neutral Bay      2089           North Sydney Council
# 9         31      Bankstown      2200   Canterbury-Bankstown Council
#
#    knn_normalised  dot_normalised  final_score
# 0        0.985048        0.036447     0.510748
# 1        0.017375        0.985281     0.501328
# 2        0.017674        0.946876     0.482275
# 3        0.023439        0.884030     0.453734
# 4        0.037878        0.815406     0.426642
# 5        0.041919        0.745666     0.393793
# 6        0.026706        0.736924     0.381815
# 7        0.093451        0.619397     0.356424
# 8        0.038114        0.607043     0.322579
# 9        0.019163        0.615150     0.317157

# %% [markdown]
# Plot the average area, distance, and population density of the suburbs against the user input suburb.

# %%
# Input data
input_index = aus_suburbs.loc[(aus_suburbs.Suburb == input_suburb['Suburb']) &
                              (aus_suburbs.City == input_suburb['City'])].index.values[0]
input_area = aus_suburbs.at[input_index, 'area']
input_density = aus_suburbs.at[input_index, 'density']
input_distance = aus_suburbs.at[input_index, 'distance']

# Get data from full suburb dataframe
top_geo = aus_suburbs.iloc[top_suburbs.Suburb_id.values]
top_geo = top_geo[['Suburb', 'Postcode', 'area', 'density', 'distance']]

# Calculate average
area_mean = np.mean(top_geo.area.values)
density_mean = np.mean(top_geo.density.values)
distance_mean = np.mean(top_geo.distance.values)

# Calculate standard deviation
area_std = np.std(top_geo.area.values)
density_std = np.std(top_geo.density.values)
distance_std = np.std(top_geo.distance.values)

# Subplot
# Create lists for the plot
input_mean = [input_area,
              input_density,
              input_distance]
mean_list = [area_mean,
             density_mean,
             distance_mean]
error_data = [area_std,
              density_std,
              distance_std]
chart_coordinates = [(0,0),
                     (0,1),
                     (1,0)]
y_labels = ['Avg size ($km^2$)',
            'Average Density ($pp/km^2$)',
            'Distance to CBD (km)']
titles = ['Suburb Size',
          'Population Density',
          'Distance to CBD']
category = [input_suburb['Suburb'],
            'Top {} suburbs'.format(top_n)]
x_pos = np.arange(len(category))

# Build the plot
fig, ax = plt.subplots(2, 2, figsize=(15,15))
fig.suptitle('Figure 6: Comparison between South Yarra and Top 10 Sydney Suburbs')
for user_input, mean, error, coord, ylabel, title in zip(input_mean,
                                                         mean_list, 
                                                         error_data,
                                                         chart_coordinates,
                                                         y_labels,
                                                         titles):
    ax[coord].bar(x_pos,
                  [user_input, mean],
                  yerr=[0, error],
                  align='center',
                  alpha=1,
                  color=('steelblue', 'coral'),
                  capsize=10)
    ax[coord].set_ylabel(ylabel)
    ax[coord].set_xticks(x_pos)
    ax[coord].set_xticklabels(category)
    ax[coord].set_title(title, y=1.01)
    ax[coord].yaxis.grid(True)


# Delete empty axes
fig.delaxes(ax[1][1])
plt.show()

# %% [markdown]
# # Top 10 suburbs with their top local venues

# %%
# aus_suburbs.iloc[top_suburbs.Suburb_id.values]

top_ven = venues_sorted.iloc[top_suburbs.Suburb_id.values]
top_ven = top_ven.drop(['Suburb_id', 'LGA', 'City'], axis=1)

# top_ven = top_ven.reindex(top_suburbs_order)

# Add input suburb to compare its local venues
input_suburb_ven_sort = venues_sorted.loc[venues_sorted.Suburb == input_suburb['Suburb']]
input_suburb_ven_sort = input_suburb_ven_sort.drop(['Suburb_id', 'LGA', 'City'], axis=1)
top_ven_with_input = pd.concat([input_suburb_ven_sort, top_ven], ignore_index=True)

# %%
top_ven_with_input
# Out:
#            Suburb  Postcode  1st Most Common Venue 2nd Most Common Venue  \
# 0     South Yarra      3141                   Café    Italian Restaurant
# 1        Woolwich      2110                   Park                   Bar
# 2      Parramatta      2150                   Café       Thai Restaurant
# 3   Woolloomooloo      2011                   Café    Italian Restaurant
# 4     Surry Hills      2010                   Café                   Pub
# 5      Crows Nest      2065                   Café   Japanese Restaurant
# 6          Coogee      2034                   Café                 Hotel
# 7       The Rocks      2000                   Café                 Hotel
# 8    North Sydney      2060                   Café                   Gym
# 9     Neutral Bay      2089    Japanese Restaurant                  Café
# 10      Bankstown      2200  Vietnamese Restaurant                  Café
#
#     3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0     Japanese Restaurant                  Hotel     Convenience Store
# 1      Italian Restaurant  Australian Restaurant                  Café
# 2            Burger Joint     Chinese Restaurant    Mexican Restaurant
# 3                   Hotel  Australian Restaurant       Thai Restaurant
# 4             Pizza Place    Japanese Restaurant        Breakfast Spot
# 5         Thai Restaurant  Vietnamese Restaurant    Italian Restaurant
# 6            Burger Joint                    Bar                  Park
# 7   Australian Restaurant                    Pub             Hotel Bar
# 8     Japanese Restaurant                    Bar             Juice Bar
# 9         Thai Restaurant            Supermarket          Liquor Store
# 10      Convenience Store   Fast Food Restaurant            Sports Bar
#
#    6th Most Common Venue  7th Most Common Venue  8th Most Common Venue  \
# 0        Thai Restaurant                    Bar          Grocery Store
# 1        Harbor / Marina                    NaN                    NaN
# 2           Dessert Shop              Juice Bar       Asian Restaurant
# 3                 Hostel     Chinese Restaurant                    Pub
# 4    Lebanese Restaurant  Vietnamese Restaurant        Thai Restaurant
# 5      Indian Restaurant                    Bar         Sandwich Place
# 6        Thai Restaurant      Fish & Chips Shop      Indian Restaurant
# 7     Italian Restaurant             Steakhouse                   Park
# 8         Sandwich Place                 Bakery  Vietnamese Restaurant
# 9                 Bakery       Asian Restaurant                    Pub
# 10      Department Store             Steakhouse    Lebanese Restaurant
#
#    9th Most Common Venue 10th Most Common Venue
# 0           Dessert Shop      French Restaurant
# 1                    NaN                    NaN
# 2    Japanese Restaurant     Italian Restaurant
# 3                    Bar             Restaurant
# 4            Karaoke Bar      Indian Restaurant
# 5     Mexican Restaurant       Asian Restaurant
# 6     Italian Restaurant       Sushi Restaurant
# 7           Cocktail Bar         Scenic Lookout
# 8                  Plaza          Grocery Store
# 9                    Spa      Mobile Phone Shop
# 10                   Gym          Grocery Store

# %% [markdown]
# Plot top suburbs venue frequencies onto bar chart

# %%
# List all of the venues in the dataframe
venues = top_ven.drop(['Suburb', 'Postcode'], axis=1)
venues = pd.DataFrame(data=venues.values.flatten())
venues = venues.dropna()
venues.rename(columns={0: "Venues"}, inplace=True)

# Group dataframe by venue and show its frequency count
venues_count = venues.groupby(['Venues']).agg({'Venues' :'count'})
venues_count.rename(columns={'Venues': 'Venues', 'Venues': 'Frequency'}, inplace=True)
venues_count.sort_values(by=['Frequency'], inplace=True, ascending=False)

# Create lists for the plot
materials = venues_count.index
y_pos = np.arange(len(materials))
values = venues_count.values.flatten()

unique_values = list(np.unique(values))
unique_values.sort(reverse=True)

bar_colours = ['tab:blue',
               'tab:orange',
               'tab:green',
               'tab:red',
               'tab:purple',
               'tab:cyan',
               'tab:brown',
               'tab:pink',
               'tab:gray',
               'tab:olive']
bar_colours_range = bar_colours[0:len(unique_values)]

# Build the plot
fig4 = plt.figure(figsize=(15,15))
for val, colour in zip(unique_values, bar_colours_range):
    mask = values == val
    plt.barh(y_pos[mask], values[mask], color=colour, align='center')
plt.xlabel('Frequency')
plt.yticks(y_pos, materials)
plt.title('Figure 7: Venue frequency', y=1.01)
plt.gca().invert_yaxis()
plt.grid(axis='x')

# %% [markdown]
# Some common venues among the top suburbs in relation to the input suburb (South Yarra, Melbourne) in descending order are:
# * Cafe
# * Japanese restuarant
# * Pizza place
# * Bar
# * Italian restuarant
# * Thai restaurant
# * Bakery
# * Park
# * Gym
# * Grocery Store

# %% [markdown]
# # Most similar suburbs on google maps

# %% [markdown]
# Get geographic data of top suburbs

# %%
top_ven_indexes = list(top_ven.index)
top_suburb_geo = aus_suburbs.iloc[top_ven_indexes]

# %% [markdown]
# Plot top suburbs onto a map

# %%
address = "Sydney, New South Wales"
geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Sydney, NSW are {}, {}.'.format(latitude, longitude))
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1316                 h.request(req.get_method(), req.selector, req.data, headers,
# -> 1317                           encode_chunked=req.has_header('Transfer-encoding'))
#    1318             except OSError as err: # timeout error
#
# ~/anaconda3/lib/python3.7/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1228         """Send a complete request to the server."""
# -> 1229         self._send_request(method, url, body, headers, encode_chunked)
#    1230
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1274             body = _encode(body, 'body')
# -> 1275         self.endheaders(body, encode_chunked=encode_chunked)
#    1276
#
# ~/anaconda3/lib/python3.7/http/client.py in endheaders(self, message_body, encode_chunked)
#    1223             raise CannotSendHeader()
# -> 1224         self._send_output(message_body, encode_chunked=encode_chunked)
#    1225
#
# ~/anaconda3/lib/python3.7/http/client.py in _send_output(self, message_body, encode_chunked)
#    1015         del self._buffer[:]
# -> 1016         self.send(msg)
#    1017
#
# ~/anaconda3/lib/python3.7/http/client.py in send(self, data)
#     955             if self.auto_open:
# --> 956                 self.connect()
#     957             else:
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#    1383
# -> 1384             super().connect()
#    1385
#
# ~/anaconda3/lib/python3.7/http/client.py in connect(self)
#     927         self.sock = self._create_connection(
# --> 928             (self.host,self.port), self.timeout, self.source_address)
#     929         self.sock.setsockopt(socket.IPPROTO_TCP, socket.TCP_NODELAY, 1)
#
# ~/anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     706     err = None
# --> 707     for res in getaddrinfo(host, port, 0, SOCK_STREAM):
#     708         af, socktype, proto, canonname, sa = res
#
# ~/anaconda3/lib/python3.7/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 8] nodename nor servname provided, or not known
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     354         try:
# --> 355             page = requester(req, timeout=timeout, **kwargs)
#     356         except Exception as error:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     524
# --> 525         response = self._open(req, data)
#     526
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _open(self, req, data)
#     542         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 543                                   '_open', req)
#     544         if result:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#
# ~/anaconda3/lib/python3.7/urllib/request.py in https_open(self, req)
#    1359             return self.do_open(http.client.HTTPSConnection, req,
# -> 1360                 context=self._context, check_hostname=self._check_hostname)
#    1361
#
# ~/anaconda3/lib/python3.7/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1318             except OSError as err: # timeout error
# -> 1319                 raise URLError(err)
#    1320             r = h.getresponse()
#
# URLError: <urlopen error [Errno 8] nodename nor servname provided, or not known>
#
# During handling of the above exception, another exception occurred:
#
# GeocoderServiceError                      Traceback (most recent call last)
# <ipython-input-30-d791b960d4de> in <module>
#       1 address = "Sydney, New South Wales"
#       2 geolocator = Nominatim(user_agent="my-application")
# ----> 3 location = geolocator.geocode(address)
#       4 latitude = location.latitude
#       5 longitude = location.longitude
#
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/osm.py in geocode(self, query, exactly_one, timeout, limit, addressdetails, language, geometry, extratags, country_codes, viewbox, bounded)
#     385
#     386         return self._parse_json(
# --> 387             self._call_geocoder(url, timeout=timeout), exactly_one
#     388         )
#     389
#
# ~/anaconda3/lib/python3.7/site-packages/geopy/geocoders/base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     384                 if "timed out" in message:
#     385                     raise GeocoderTimedOut('Service timed out')
# --> 386             raise GeocoderServiceError(message)
#     387
#     388         if hasattr(page, 'getcode'):
#
# GeocoderServiceError: [Errno 8] nodename nor servname provided, or not known

# %%
# create map of Sydney using latitude and longitude values
map_sydney = folium.Map(location=[latitude, longitude], zoom_start=12)
# add markers to map
for lat, lng, suburb, postcode, lga in zip(top_suburb_geo['LAT'],
                                           top_suburb_geo['LON'],
                                           top_suburb_geo['Suburb'],
                                           top_suburb_geo['Postcode'],
                                           top_suburb_geo['LGA']):
    #print(lat, lng)
    label = '{}, {}, {}'.format(suburb, postcode, lga)
    label = folium.Popup(label, parse_html=True)

    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_sydney)  
    
map_sydney

# %% [markdown]
# # Discussion and conclusions

# %% [markdown]
# The aim of this project was to develop a content-based recommendation system to return a list of suburbs from a city that are similar to the user's ideal suburb. The attributes that were used to measure the degree of similarty were suburb size, the suburb's distance to the cbd, population density, and the top local venues.
#
# KNN
# A KNN (kth Nearest Neighbour) coupled with pairwise euclidean distance measurement was used to find the most similar suburbs in regards to size, distance, and density. KNN was an appropriate choice because of the low dimensionality (3-dimensions) and high density of the data. Before measuring the nearest neighbour distances, a PCA analysis was performed to reduce the dimensionality of the data. PCA results show that PC1 accounts for almost 75% of the total variation of principle components while PC2 accounts for almost 15% (Figure 1). Together these two axis would account for the vast majority of the  variation of the data and would be a good approximation of a three dimensional graph (Figure 2).
#
# Afterwards, KNN distances were calculated from the PCA transformed data (Figure 3). The distances were inversed and normalised to show the degree of similarity where values close to 1 suggested that those suburbs were most similar and values closer to 0 were less similar. The results show that the suburbs that were most similar in Sydney to South Yarra are the following:
#
# |Suburb         | KNN normalised |
# |---------------|----------------|
# |Woolwich       |0.99            |
# |Kensington     |0.22            |
# |Believue Hill  |0.22            |
# |Greenwich      |0.21            |
# |Leichhardt     |0.15            |
# |Rozelle        |0.13            |
# |Lilyfield      |0.12            |
# |Longueville    |0.12            |
# |Drummoyne      |0.12            |
# |Cammeray       |0.11            |
#
# The area, density, and distance values from the recommended suburbs were then plotted as bar charts and compared with the input suburb (South Yarra) (Figure 4). Here we see that although the population density and distance to the cbd for South Yarra are within approximation of the top 10 most similar suburbs from Sydney, the South Yarra suburb size is significantly larger than the listed suburbs from Sydney, however this could be expected since Sydney's geography is denser than Melbourne. From the results, we see that Kensington is the most similar suburb followed by Leichhardt and Randwick. The specificity of the results can be further improved by including local demographic data.
#
# Dot Product
# To quantify the degree of similarity in regards to top venues, the dot product was calculated between the user input's suburb venue array and sydney suburb's venue matrix. Here the dot product value was then normalised between 1 and 0, where 1 indicates there are more common features between the input suburb (South Yarra) and the destination suburb (Sydney suburb). The results show that the most similar suburb in regards to local venues alone include Parramatta, Woolomoollo, and Crows nest.
#
# |Suburb         | Dot product normalised |
# |---------------|------------------------|
# |Parramatta     |1.00                    |
# |Woolloomoolo   |0.89                    |
# |Crows Nest     |0.76                    |
# |Surry Hills    |0.66                    |
# |The Rocks      |0.64                    |
# |Darlinghurst   |0.59                    |
# |Glebe          |0.55                    |
# |Bankstown      |0.54                    |
# |Chippendale    |0.54                    |
# |Coogee         |0.53                    |
#
# One thing that should be taken into account is the availability of data for the local venues. Since the dot product relies on the sum of products between aligned attributes, missing local venues can significantly lower the final dot product score. Also, data wrangling with the local venue categories can further improve the results by grouping together similar categories such as 'coffee shop' and 'cafe'.
#
# KNN and Dot product combined
# An attempt to list similar suburbs by considering all the attributes (suburb size, population density, distance to cbd, and local venues) was implemented by finding the average score betweeen the KNN normalised value and the dot product normalised value and ranking them in descending order. The following suburbs were listed:
#
# |Suburb       |KNN normalised|dot product normalised|Final score|
# |-------------|--------------|----------------------|-----------|
# |Leichhardt   |0.15          |0.49                  |0.07       |
# |North Sydney |0.09          |0.45                  |0.04       |
# |Woolwich     |0.99          |0.04                  |0.04       |
# |Kensington   |0.22          |0.16                  |0.04       |
# |Glebe        |0.05          |0.65                  |0.03       |
# |Crows Nest   |0.04          |0.77                  |0.03       |
# |Lilyfield    |0.12          |0.21                  |0.03       |
# |Coogee       |0.04          |0.59                  |0.02       |
# |Greenwich    |0.22          |0.10                  |0.02       |
# |Cammeray     |0.11          |0.19                  |0.02       |
#
# Here we see that suburbs such as Crows Nest and Coogee have very low KNN scores which suggests that these suburbs are not very similar to the input suburb (South Yarra) in regards to either suburb size, distance to cbd, or population density. While at the same time, the suburbs have a significantly higher dot product scores which means that these suburbs are similar to South Yarra in regards to their local venues. This can be overcome by applying a threshold where suburbs that are too different in either category can are automatically removed from the list. However, determining this threshold quantitatively is a non-trivial task.
